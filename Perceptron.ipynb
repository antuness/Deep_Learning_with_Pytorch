# %% [markdown]
# # **Classificação Linear**

# %% [markdown]
# # **Equação da reta**
#
# ![equação_da_reta.JPG](data:image/jpeg;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = -1
b = 4
c = 0.4

## ax + by + c = 0
## y = (-a*x - c) / b

## x em um intervalo de valores de -2 até 4, e eu quero 50 valores
x = np.linspace(-2,4,50)
y = (-a*x - c)/b

plt.plot(x,y)
plt.grid(True)

# %%
## Para eu resolver a equação da reta para diferentes pontos da reta no espaço, eu preciso transformar a reta acima em uma
## eu preciso transformar a reta acima em uma função

# %%
a = -1
b = 4
c = 0.4

def plotline(a,b,c):
  x = np.linspace(-2,4,50)
  y = (-a*x - c)/b

plt.plot(x,y)
plt.grid(True)
plotline(a,b,c)

# %% [markdown]
# # **Solucionando a equação da reta para diferentes pontos**

# %%
a = -1
b = 4
c = 0.4

def plotline(a,b,c):
  x = np.linspace(-2,4,50)
  y = (-a*x - c)/b

plt.plot(x,y)
plt.grid(True)
plotline(a,b,c)


p1 = (2, 0.4)
p2 = (1, 0.6)
p3 = (3, -0.4)

ret1 = a*p1[0] + b*p1[1] + c
ret2 = a*p2[0] + b*p2[1] + c
ret3 = a*p3[0] + b*p3[1] + c


plotline(a,b,c)
plt.plot(p1[0], p1[1], color ='b', marker='o')
plt.plot(p2[0], p2[1], color ='r', marker='o')
plt.plot(p3[0], p3[1], color ='g', marker='o')

# %%
ret1 = a*p1[0] + b*p1[1] + c
print("%.2f" % ret1)

ret2 = a*p2[0] + b*p2[1] + c
print("%.2f" % ret2)

ret3 = a*p3[0] + b*p3[1] + c
print("%.2f" % ret3)
# Out:
# 0.00
# 1.80
# -4.20

# %% [markdown]
# ![retas.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Modelo Linear**
#
# ![modelo_linear.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![modelo_linear_2.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# # **Regra Geral**
#
# ![modelo_linear_3.jpg](data:image/jpeg;base64,...)

# %%
## No caso de 2 dimensões
## b = bias
## w = pesos
## y = w1*x1 + w2*x2 + b

# %%
## No caso de 3 dimensões
## y = w1*x1 + w2*x2 + w3*x3 + b
## e assim por diante

# %% [markdown]
# # **Equação do Perceptron**
#
# É justamente a regra que fizemos acima
#
# ![modelo_linear_4.JPG](data:image/jpeg;base64,...)
